# %%
import pandas as pd 
import matplotlib as plt
import seaborn as sns
data= pd.read_csv('cwurData.csv')
data.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
data.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
data.iloc[:]
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df = data[['world_rank','score']]
sns.lineplot(x = df.world_rank, y = df.score)

#thats weird
# Out:
# <AxesSubplot:xlabel='world_rank', ylabel='score'>

# %%
data2.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
data = data2[["country", "student_staff_ratio"]].groupby(["country"], as_index=False).mean()
data.dropna(axis = 0,subset = ['student_staff_ratio'], inplace = True)
data.head(100)


#sns.scatterplot(x = data.country, y = data.student_staff_ratio)
sns.scatterplot(x = data2.student_staff_ratio , y = data2.world_rank)
# Out:
# <AxesSubplot:xlabel='student_staff_ratio', ylabel='world_rank'>

# %%
import numpy as np

a = np.nan
print(a)




def cool(hi):
    if  (hi.split(':')[0]) != '-' and type (hi.split(':')[1]) != '-' :
        if int(hi.split(':')[0])> int(hi.split(':')[1]):
            return "female"
        else:
            return "male"
    else:
        return np.nan
    
    
    
    
data2['female_male_ratio']= data2['female_male_ratio'].map(cool)

data2
# Out:
# nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-00c9f171c7c9> in <module>
#      19
#      20
# ---> 21 data2['female_male_ratio']= data2['female_male_ratio'].map(cool)
#      22
#      23 data2
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3968         dtype: object
#    3969         """
# -> 3970         new_values = super()._map_values(arg, na_action=na_action)
#    3971         return self._constructor(new_values, index=self.index).__finalize__(
#    3972             self, method="map"
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# ...

# %%
data.head()
data[["Home Adress", "Promoted"]].groupby(["Home Adress"], as_index=True).mean()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
data2 = pd.read_csv('timesData.csv')
data2
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# ...

# %%
def cool(hi):
    try:
        if int(hi.split(':')[0])> int(hi.split(':')[1]):
            return "female"
        else:
            return "male"
    except:
        return np.nan
    
data2['female_male_ratio']= data2['female_male_ratio'].map(cool)
data2= data2.dropna(axis=0, subset=["female_male_ratio"])


data2
# Out:
#      world_rank                        university_name  \
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# 5             6                University of Cambridge
# ...         ...                                    ...
# 2597    601-800                      Xidian University
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 1     United States of America      97.7          54.6      98.0       99.9
# 2     United States of America      97.8          82.3      91.4       99.9
# ...

# %%
data2[10:]
# Out:
#      world_rank                                    university_name  \
# 11           12                              University of Chicago
# 12           13                           Johns Hopkins University
# 13           14                                 Cornell University
# 14           15  ETH Zurich – Swiss Federal Institute of Techno...
# 15           15                             University of Michigan
# ...         ...                                                ...
# 2597    601-800                                  Xidian University
# 2598    601-800                                Yeungnam University
# 2599    601-800                        Yıldız Technical University
# 2601    601-800                       Yokohama National University
# 2602    601-800                                 Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 11    United States of America      79.1          62.8      87.9       96.9
# ...

# %%
df1 = data2.loc[data2['female_male_ratio'] == 'male']
df2 = data2.loc[data2['female_male_ratio'] == 'female']

sns.FacetGrid(data=data2, col="female_male_ratio").map(sns.histplot, "research")
sns.histplot(data=df2, x="research")
# Out:
# <AxesSubplot:title={'center':'female_male_ratio = female'}, xlabel='research', ylabel='Count'>
